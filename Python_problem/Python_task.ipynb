# %% [markdown]
# # Python Problem

# %% [markdown]
# ## Library Used: tweepy
# It is a python library for accessing the Twitter API with a lot of functionality to make the task easier

# %% [markdown]
# ## Keys for OAuth Authentication

# %%
consumer_key="your_consumer_key"
consumer_secret="your_consumer_secret"
access_token="your_access_token"
access_token_secret="your_access_token_secret"

# %% [markdown]
# ## OAuth Authentication
# To use the Twitter Api we need to perform OAuth

# %%
import json
import tweepy

#using the keys to perform OAuth
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ## Testing out the Library Features
#
# Testing tweepy library to obtain the required features from a tweet.<br/>
# The features are:<br/>
# ● The text of the tweet.<br/>
# ● Date and time of the tweet.<br/>
# ● The number of favorites/likes.<br/>
# ● The number of retweets.<br/>
# ● Image in text.<br/>

# %%
#Name: contains the twitter handle of the user
#tweetcounf: contains the number of tweets to fetch
name="midasIIITD"
tweetcount=20

#using the api to get the user's tweets
results=api.user_timeline(id=name,count=tweetcount)
i=0

#desiplaying data of a tweet
for tweet in results:
    i+=1
    tweet.text
    print(i,": ",tweet.retweet_count,tweet.favorite_count,tweet.created_at,tweet.entities)
    #print(tweet.text,len([medium['type'] == 'photo' for medium in tweet.entities['media']]))
    try:
        print(len([m["type"]=="photo" for m in tweet .entities["media"]]))
        print()
    except:
        print("No picture in this tweet")
        print()
    break
# Out:
# 1 :  9 0 2019-04-09 16:45:07 {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'IIITDelhi', 'name': 'IIIT Delhi', 'id': 2227868629, 'id_str': '2227868629', 'indices': [3, 13]}], 'urls': []}
# No picture in this tweet

# %% [markdown]
# ## Testing the Cursor object
# The cursor object of Tweepy facilitates pagination and hence allows us to retrieve more than 200 tweets(the max number of tweets in a page).The Twitter Api can fetch max of 3200 tweets using pagination.<br/>
# Here we will use the Cursor object to obtain all the tweets of **midasIIITD**.

# %%
#Using the Cursor object to fetch the tweets
#printing the required features and forming a list of dictionary of required features for testing purposes

statuses=[]
for status in tweepy.Cursor(api.user_timeline, screen_name='@midasIIITD',tweet_mode="extended").items():
    text=status.full_text
    time=status.created_at
    fav=status.favorite_count
    retweet=status.retweet_count
    statuses.append({'text':text,'date_time':time,'favourites':fav,"retweets:":retweet})
    break
statuses
# Out:
# [{'text': 'RT @IIITDelhi: We are delighted to share that IIIT-Delhi is ranked 55 by NIRF this year. We have moved up by 11 positions compared to the p…',
#   'date_time': datetime.datetime(2019, 4, 9, 16, 45, 7),
#   'favourites': 0,
#   'retweets:': 9}]

# %% [markdown]
# ## Using the Cursor object to Fetch all the Tweets
# We use the tweepy Cursor object to fetch all the tweets and store it in a list.

# %%
#Making a list of the status objects (tweets) returned by the Cursor object.

status=[stat for stat in tweepy.Cursor(api.user_timeline, screen_name='@midasIIITD',tweet_mode="extended").items()]

# %% [markdown]
# ## Dumping the Tweets into JSONlines File
# The Status object of tweepy itself is not JSON serializable, but it has a _json property which contains JSON serializable response data. Using this property we dump the tweets into JSONlines file.<br/>
# We use the open and write methods from the **jsonlines** library to dump the tweets

# %%
#Dumping the fetched tweets into JSONlines file.

import jsonlines
with jsonlines.open('out.jsonl', mode='w') as writer:
    for stat in status:
        writer.write(stat._json)

# %% [markdown]
# ## Checking the JSONlines File

# %%
#Reading from the JSONlines file and checking the features.

with jsonlines.open('out.jsonl') as reader:
    for obj in reader.iter(type=dict):
        print(obj["full_text"])
        print(obj["favorite_count"])
        print(obj["created_at"])
        break
# Out:
# RT @IIITDelhi: We are delighted to share that IIIT-Delhi is ranked 55 by NIRF this year. We have moved up by 11 positions compared to the p…
# 0
# Tue Apr 09 16:45:07 +0000 2019

# %% [markdown]
# ## Parsing the File
# To parse the JSONlines File we use **pandas** library.<br/>
# We form a dataframe to store the required features of the text in tabular format:<br/>
# ● The text of the tweet.<br/>
# ● Date and time of the tweet.<br/>
# ● The number of favorites/likes.<br/>
# ● The number of retweets.<br/>
# ● Number of Images present in Tweet. If no image returns None.<br/><br/>
# We first read the JSONlines file into the dataframe.

# %%
import pandas as pd

#reading jsonlines using the lines=True argument
data=pd.read_json('out.jsonl', lines=True)

# %% [markdown]
# ## Decription of the dataframe

# %%
data.describe()
# Out:
#        contributors  coordinates  favorite_count  geo            id  \
# count           0.0          0.0      342.000000  0.0  3.420000e+02
# mean            NaN          NaN        2.339181  NaN  1.071922e+18
# std             NaN          NaN        3.964895  NaN  3.153947e+16
# min             NaN          NaN        0.000000  NaN  1.021378e+18
# 25%             NaN          NaN        0.000000  NaN  1.035726e+18
# 50%             NaN          NaN        0.000000  NaN  1.082049e+18
# 75%             NaN          NaN        3.750000  NaN  1.098112e+18
# max             NaN          NaN       24.000000  NaN  1.115657e+18
#
#              id_str  in_reply_to_status_id  in_reply_to_status_id_str  \
# count  3.420000e+02           5.300000e+01               5.300000e+01
# mean   1.071922e+18           1.077279e+18               1.077279e+18
# std    3.153947e+16           3.058072e+16               3.058072e+16
# min    1.021378e+18           1.024582e+18               1.024582e+18
# 25%    1.035726e+18           1.051777e+18               1.051777e+18
# 50%    1.082049e+18           1.088018e+18               1.088018e+18
# 75%    1.098112e+18           1.102221e+18               1.102221e+18
# max    1.115657e+18           1.114888e+18               1.114888e+18
#
#        in_reply_to_user_id  in_reply_to_user_id_str  place  \
# count         6.900000e+01             6.900000e+01    0.0
# mean          5.710079e+17             5.710079e+17    NaN
# std           4.937548e+17             4.937548e+17    NaN
# min           5.694822e+06             5.694822e+06    NaN
# 25%           2.227869e+09             2.227869e+09    NaN
# 50%           9.328474e+17             9.328474e+17    NaN
# 75%           1.021356e+18             1.021356e+18    NaN
# max           1.114472e+18             1.114472e+18    NaN
#
#        possibly_sensitive  quoted_status_id  quoted_status_id_str  \
# count               149.0      1.800000e+01          1.800000e+01
# mean                  0.0      1.057190e+18          1.057190e+18
# std                   0.0      2.934397e+16          2.934397e+16
# min                   0.0      1.021697e+18          1.021697e+18
# 25%                   0.0      1.031845e+18          1.031845e+18
# 50%                   0.0      1.052272e+18          1.052272e+18
# 75%                   0.0      1.077278e+18          1.077278e+18
# max                   0.0      1.111675e+18          1.111675e+18
#
#        retweet_count
# count     342.000000
# mean       57.461988
# std       471.614949
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%        11.000000
# max      8430.000000

# %% [markdown]
# ## Looking at the Head of the dataframe

# %%
data.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2019-04-09 16:45:07           [0, 140]
# 1           NaN          NaN 2019-04-09 05:04:27           [0, 136]
# 2           NaN          NaN 2019-04-09 05:04:11           [0, 140]
# 3           NaN          NaN 2019-04-08 19:38:09           [0, 140]
# 4           NaN          NaN 2019-04-08 07:08:12           [0, 279]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'MIDAS', 'indices': [25...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2                                                NaN               0
# 3                                                NaN               0
# 4  {'media': [{'id': 1115149307798224898, 'id_str...              16
#
#    favorited                                          full_text  geo  \
# 0      False  RT @IIITDelhi: We are delighted to share that ...  NaN
# 1      False  RT @Harvard: Professor Jelani Nelson founded A...  NaN
# 2      False  RT @emnlp2019: For anyone interested in submit...  NaN
# 3      False  RT @multimediaeval: Announcing the 2019 MediaE...  NaN
# 4      False  Many Congratulations to @midasIIITD student, S...  NaN
#
#                          ...                          quoted_status  \
# 0                        ...                                    NaN
# 1                        ...                                    NaN
# 2                        ...                                    NaN
# 3                        ...                                    NaN
# 4                        ...                                    NaN
#
#    quoted_status_id quoted_status_id_str  quoted_status_permalink  \
# 0               NaN                  NaN                      NaN
# 1               NaN                  NaN                      NaN
# 2               NaN                  NaN                      NaN
# 3               NaN                  NaN                      NaN
# 4               NaN                  NaN                      NaN
#
#    retweet_count  retweeted  \
# 0              9      False
# 1             35      False
# 2             13      False
# 3             15      False
# 4              2      False
#
#                                     retweeted_status  \
# 0  {'created_at': 'Tue Apr 09 09:03:12 +0000 2019...
# 1  {'created_at': 'Mon Apr 08 20:10:01 +0000 2019...
# 2  {'created_at': 'Mon Apr 08 17:35:00 +0000 2019...
# 3  {'created_at': 'Mon Mar 18 06:40:38 +0000 2019...
# 4                                                NaN
#
#                                               source truncated  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...     False
# 1  <a href="http://twitter.com" rel="nofollow">Tw...     False
# 2  <a href="http://twitter.com" rel="nofollow">Tw...     False
# 3  <a href="http://twitter.com" rel="nofollow">Tw...     False
# 4  <a href="http://twitter.com" rel="nofollow">Tw...     False
#
#                                                 user
# 0  {'id': 1021355762575073281, 'id_str': '1021355...
# 1  {'id': 1021355762575073281, 'id_str': '1021355...
# 2  {'id': 1021355762575073281, 'id_str': '1021355...
# 3  {'id': 1021355762575073281, 'id_str': '1021355...
# 4  {'id': 1021355762575073281, 'id_str': '1021355...
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Dataframe columns/features
# As noted we dont require all these columns(features) and we require some other columns(features) as well such as number of images.

# %%
data.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status_permalink',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')

# %% [markdown]
# ## Picking the required columns/features

# %%
#assinging the current dataframe its on subset containing only the required features
cols_of_interest=["full_text","created_at","favorite_count","retweet_count","entities"]
data = data[cols_of_interest]

# %% [markdown]
# ## Forming the images column
# Forming the images column using the entities column.The images column contains the no. of images in a tweet if images are present else it gives Nan(None).We then delete entities column as we no longer require it.

# %%
#list to store the image values
images=[]
#parsing over the entire datafram and appending the number of images present to the list
for i in range(len(data)):
    val=data.iloc[i]["entities"].get("media",None)
    if(type(val)==type([])):
        images.append(len(val))
    else:
        images.append(None)
        
#making a new column and assigning it the value of number of images
data["Number of images"]=images

#deleting entities column as its no longer needed
del data["entities"]

#printing the Number of images column that we just formed
data["Number of images"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      1.0
# 5      1.0
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     1.0
# 15     NaN
# 16     NaN
# 17     1.0
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#       ...
# 312    NaN
# 313    NaN
# 314    1.0
# 315    NaN
# 316    1.0
# 317    NaN
# 318    NaN
# 319    NaN
# 320    NaN
# 321    1.0
# 322    NaN
# 323    NaN
# 324    1.0
# 325    NaN
# 326    NaN
# 327    NaN
# 328    NaN
# 329    NaN
# 330    NaN
# 331    NaN
# 332    NaN
# 333    NaN
# 334    NaN
# 335    NaN
# 336    NaN
# 337    NaN
# 338    NaN
# 339    1.0
# 340    NaN
# 341    NaN
# Name: Number of images, Length: 342, dtype: float64

# %% [markdown]
# ## Renaming columns and displaying Head

# %%
#renaming the columns to more convinient and easy to understand names
data.rename(columns={'full_text':'Text','created_at':'Date and Time','favorite_count':'Number of favorites',
                    'retweet_count':'Number of retweete'}, inplace=True)
data.head()
# Out:
#                                                 Text       Date and Time  \
# 0  RT @IIITDelhi: We are delighted to share that ... 2019-04-09 16:45:07
# 1  RT @Harvard: Professor Jelani Nelson founded A... 2019-04-09 05:04:27
# 2  RT @emnlp2019: For anyone interested in submit... 2019-04-09 05:04:11
# 3  RT @multimediaeval: Announcing the 2019 MediaE... 2019-04-08 19:38:09
# 4  Many Congratulations to @midasIIITD student, S... 2019-04-08 07:08:12
#
#    Number of favorites  Number of retweete  Number of images
# 0                    0                   9               NaN
# 1                    0                  35               NaN
# 2                    0                  13               NaN
# 3                    0                  15               NaN
# 4                   16                   2               1.0

# %% [markdown]
# # The Final Required Table

# %%
#printing the final table
data
# Out:
#                                                   Text       Date and Time  \
# 0    RT @IIITDelhi: We are delighted to share that ... 2019-04-09 16:45:07
# 1    RT @Harvard: Professor Jelani Nelson founded A... 2019-04-09 05:04:27
# 2    RT @emnlp2019: For anyone interested in submit... 2019-04-09 05:04:11
# 3    RT @multimediaeval: Announcing the 2019 MediaE... 2019-04-08 19:38:09
# 4    Many Congratulations to @midasIIITD student, S... 2019-04-08 07:08:12
# 5    @midasIIITD thanks all students who have appea... 2019-04-08 03:27:42
# 6    @himanchalchandr Meanwhile, complete CV/NLP ta... 2019-04-07 14:17:29
# 7    @sayangdipto123 Submit as per the guideline ag... 2019-04-07 14:17:09
# 8    We request all students whose interview are sc... 2019-04-07 11:43:24
# 9    Other queries: "none of the Tweeter Apis give ... 2019-04-07 06:55:19
# 10   Other queries: "do we have to make two differe... 2019-04-07 06:53:38
# 11   Other queries: "If using Twitter api, it does ... 2019-04-07 05:32:27
# 12   Response to some queries asked by students on ... 2019-04-07 05:29:40
# 13   RT @kdnuggets: Top 8 #Free Must-Read #Books on... 2019-04-06 17:11:29
# 14   @nupur_baghel @PennDATS Congratulation @nupur_... 2019-04-06 16:43:27
# 15   We have emailed the task details to all candid... 2019-04-05 16:08:37
# 16   RT @rfpvjr: Our NAACL paper on polarization in... 2019-04-05 04:05:11
# 17   RT @kdnuggets: Effective Transfer Learning For... 2019-04-05 04:04:43
# 18   RT @stanfordnlp: What’s new in @Stanford CS224... 2019-04-03 18:31:53
# 19   RT @DeepMindAI: Today we're releasing a large-... 2019-04-03 17:04:32
# 20   RT @ylecun: Congratulations Jitendra Malik !\n... 2019-04-03 09:03:40
# 21   RT @IIITDelhi: Another chance to take admissio... 2019-04-03 07:46:02
# 22   Dear @midasIIITD internship candidates who hav... 2019-04-02 04:20:13
# 23   Looking forward to your paper submission to @I... 2019-04-02 02:44:54
# 24   RT @ngrams: Reproducibility in multimedia rese... 2019-04-02 02:35:44
# 25   Online application for https://t.co/DJFDrQsHZP... 2019-04-01 06:53:08
# 26   RT @ACMMM19: A final reminder of the Reproduci... 2019-03-31 10:21:24
# 27   RT @isarth23: Thanks for the support and help ... 2019-03-29 19:43:24
# 28   Since SemEval-2019 will be held June 6-7, 2019... 2019-03-29 17:16:40
# 29   +@aggarwal_kartik.\nCongrats! Wish you many mo... 2019-03-29 17:04:30
# ..                                                 ...                 ...
# 312  RT @TensorFlow: TensorFlow 1.10.0 has been rel... 2018-08-09 05:59:57
# 313  @midasIIITD is looking for motivated IIITD MTe... 2018-08-08 11:30:56
# 314  @IIITDelhi @ponguru @RatnRajiv The results of ... 2018-08-08 05:53:48
# 315  RT @IIITDelhi: @midasIIITD has secured rank 1 ... 2018-08-08 05:45:58
# 316  RT @kdnuggets: Comparison of Top 6 Python NLP ... 2018-08-07 07:16:33
# 317  Check more details of the 20th IEEE Internatio... 2018-08-07 02:05:12
# 318  MR2AMC@ISM 2018 will be organized by @RatnRaji... 2018-08-07 01:58:49
# 319  Our workshop proposal named, "MR2AMC: Multimod... 2018-08-07 01:50:33
# 320  @NUSComputing Congratulations Abdelhak and Pro... 2018-08-06 17:48:23
# 321  RT @goodfellow_ian: One of the most anticipate... 2018-08-06 17:46:59
# 322     @the_dhumketu Great to have you in @midasIIITD 2018-08-06 06:06:47
# 323  Congratulation @soujanyaporia for being appoin... 2018-08-03 05:56:33
# 324  @IIITDelhi @the_dhumketu Thanks team @midasIII... 2018-08-01 11:47:15
# 325  RT @IIITDelhi: Congratulations @midasIIITD int... 2018-08-01 11:20:07
# 326  RT @learning_pt: Profile of the 5 Indian under... 2018-08-01 05:06:47
# 327  Have a look at the list of accepted papers in ... 2018-07-31 12:11:52
# 328  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te... 2018-07-31 02:06:26
# 329  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ... 2018-07-30 07:30:51
# 330  RT @ylecun: Jitendra Malik, who directs FAIR-M... 2018-07-28 11:07:11
# 331  RT @kdnuggets: .@Bloomberg launches free cours... 2018-07-28 06:14:09
# 332  RT @TechAtBloomberg: Missed #PyLondinium18? Wa... 2018-07-28 06:13:48
# 333  RT @IIITDelhi: We are delighted to announce th... 2018-07-28 04:08:21
# 334  Get ready for the annual technical fest of @II... 2018-07-27 06:46:44
# 335  Congratulations Dr. @RatnRajiv and team @midas... 2018-07-27 04:07:31
# 336  Congratulations MIDAS @midasIIITD intern Prakh... 2018-07-25 05:14:35
# 337    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm 2018-07-24 10:33:23
# 338  It feels great to be the part of @IIITDelhi. h... 2018-07-24 10:12:34
# 339  Thank you, @toonzratn for designing the logo o... 2018-07-24 09:46:26
# 340  We are on Facebook too. Like our page to get o... 2018-07-23 16:25:05
# 341  MIDAS is a group of researchers at IIIT-Delhi ... 2018-07-23 12:53:15
#
#      Number of favorites  Number of retweete  Number of images
# 0                      0                   9               NaN
# 1                      0                  35               NaN
# 2                      0                  13               NaN
# 3                      0                  15               NaN
# 4                     16                   2               1.0
# 5                      5                   0               1.0
# 6                      0                   0               NaN
# 7                      0                   0               NaN
# 8                      1                   1               NaN
# 9                      5                   2               NaN
# 10                     4                   1               NaN
# 11                     6                   1               NaN
# 12                     7                   1               NaN
# 13                     0                   2               NaN
# 14                    18                   3               1.0
# 15                    11                   1               NaN
# 16                     0                  16               NaN
# 17                     0                  11               1.0
# 18                     0                  59               NaN
# 19                     0                 871               NaN
# 20                     0                  16               NaN
# 21                     0                   4               NaN
# 22                     8                   1               NaN
# 23                     5                   1               NaN
# 24                     0                   7               NaN
# 25                     7                   2               NaN
# 26                     0                  10               NaN
# 27                     0                   2               NaN
# 28                     9                   1               NaN
# 29                     2                   0               NaN
# ..                   ...                 ...               ...
# 312                    0                 265               NaN
# 313                    2                   1               NaN
# 314                    3                   1               1.0
# 315                    0                   1               NaN
# 316                    0                  40               1.0
# 317                    1                   1               NaN
# 318                    1                   1               NaN
# 319                    1                   1               NaN
# 320                    0                   0               NaN
# 321                    0                 103               1.0
# 322                    0                   0               NaN
# 323                    6                   1               NaN
# 324                    5                   1               1.0
# 325                    0                   4               NaN
# 326                    0                   4               NaN
# 327                    1                   0               NaN
# 328                    0                 264               NaN
# 329                    0                   2               NaN
# 330                    0                  57               NaN
# 331                    0                 105               NaN
# 332                    0                   7               NaN
# 333                    0                   6               NaN
# 334                    3                   2               NaN
# 335                    8                   2               NaN
# 336                    5                   1               NaN
# 337                    2                   1               NaN
# 338                    2                   1               NaN
# 339                    4                   1               1.0
# 340                    3                   1               NaN
# 341                    7                   4               NaN
#
# [342 rows x 5 columns]
